# %%
import pandas as pd
import numpy as np

df=pd.read_csv("marketing_campaign_data_messy.csv").head()

df
# Out:
#    Campaign_ID              Campaign_Name           Start_Date    End_Date  \
# 0     CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1     CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2     CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3     CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4     CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
#
#     Channel  Impressions  Clicks     Spend  Conversions Active  Clicks  \
# 0    TikTok        16795      197  $102.82         20.0      Y     NaN
# 1  Facebook         1860       30    24.33          1.0      0     NaN
# 2     Email        77820      843  1323.39         51.0     No     NaN
# 3    TikTok        55886     2019  2180.38        135.0   True     NaN
# 4  Facebook         7265      169   252.44         30.0    Yes     NaN
#
#   Campaign_Tag
# 0           TI
# 1           FA
# 2           EM
# 3           TI
# 4           FA

# %%
#-------------------------------------------
# Step 1 : Cleaning Headers and Column names
#-------------------------------------------

print(df.columns.to_list())

df.columns=df.columns.str.strip().str.lower().str.replace(' ','_')

print("Fix")

df.columns=df.columns.to_list()

print(df.columns.to_list())
# Out:
# [' Campaign_ID ', 'Campaign_Name', 'Start_Date', 'End_Date', 'Channel', 'Impressions', 'Clicks ', 'Spend', 'Conversions', 'Active', 'Clicks', 'Campaign_Tag']
# Fix
# ['campaign_id', 'campaign_name', 'start_date', 'end_date', 'channel', 'impressions', 'clicks', 'spend', 'conversions', 'active', 'clicks', 'campaign_tag']

# %%
df.head()
# Out:
#   campaign_id             campaign_name           start_date    end_date  \
# 0   CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1   CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2   CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3   CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4   CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
#
#     channel  impressions  clicks    spend  conversions active  clicks  \
# 0    TikTok        16795     197  $102.82         20.0      Y     NaN
# 1  Facebook         1860      30    24.33          1.0      0     NaN
# 2     Email        77820     843  1323.39         51.0     No     NaN
# 3    TikTok        55886    2019  2180.38        135.0   True     NaN
# 4  Facebook         7265     169   252.44         30.0    Yes     NaN
#
#   campaign_tag
# 0           TI
# 1           FA
# 2           EM
# 3           TI
# 4           FA

# %%
#-----------------------------------------------
#Type conversion and currency cleaning
#-----------------------------------------------


# Step 1: Convert to string
df['spend'] = df['spend'].astype(str)

# Step 2: Remove dollar sign and commas manually
df['spend'] = df['spend'].str.replace('$', '').str.replace(',', '')

# Step 3: Convert back to numbers
df['spend'] = pd.to_numeric(df['spend'])

print("after cleaning spend column :   ")
df['spend']
# Out:
# after cleaning spend column :
# 0     102.82
# 1      24.33
# 2    1323.39
# 3    2180.38
# 4     252.44
# Name: spend, dtype: float64

# %%
#-------------------------------------------
#step 3 :categorical Typos
#-------------------------------------------

print(df['channel'].unique())  # hence here it is not working due to data set 
#this block of code is available in demo.ipynb with the data set demo.csv
# Out:
# ['TikTok' 'Facebook' 'Email']

# %%
#-------------------------------------------
# Step 4: Handling missed booleans
#-------------------------------------------

df['active'].unique()

clean_boolean={
    "yes":'True',
    "no":'False',
    "Y":'True',
    "N":'False',
    "N/A":'np.nan',
    '0':'False',
    '1':'True',
    'Yes':'True',
    'No':'False'
}

df['active']=df['active'].replace(clean_boolean)

df['active'].unique()
print("full data set after cleaning boolean : ")
df
# Out:
# full data set after cleaning boolean :
#   campaign_id             campaign_name           start_date    end_date  \
# 0   CMP-00001       Q4_Summer_CMP-00001  2023-11-24 00:00:00  2023-12-13
# 1   CMP-00002       Q1_Launch_CMP-00002  2023-05-06 00:00:00  2023-05-12
# 2   CMP-00003       Q3_Winter_CMP-00003  2023-12-13 00:00:00  2023-12-20
# 3   CMP-00004  Q1_BlackFriday_CMP-00004           2023-10-30  2023-11-03
# 4   CMP-00005       Q2_Winter_CMP-00005  2023-04-22 00:00:00  2023-04-23
#
#     channel  impressions  clicks    spend  conversions active  clicks  \
# 0    TikTok        16795     197   102.82         20.0   True     NaN
# 1  Facebook         1860      30    24.33          1.0  False     NaN
# 2     Email        77820     843  1323.39         51.0  False     NaN
# 3    TikTok        55886    2019  2180.38        135.0   True     NaN
# 4  Facebook         7265     169   252.44         30.0   True     NaN
#
#   campaign_tag
# 0           TI
# 1           FA
# 2           EM
# 3           TI
# 4           FA

# %%
#-------------------------------------------
# Step 5 : Date parsing
#-------------------------------------------

df['start_date'].dtype # initially the data type is object
df['start_date'] = pd.to_datetime(df['start_date'], format="%Y/%m/%d", errors='coerce')
df['start_date'].dtype # after conversion the data type is datetime64[ns]
# Out:
# dtype('<M8[ns]')

# %%
#-------------------------------------------
# Step 6 : feature extraction for the season without using if else condition
#-------------------------------------------

def get_season(campaign_name):
    if 'spring' in campaign_name.lower():
        return 'spring'
    elif 'summer' in campaign_name.lower():
        return 'summer'
    elif 'fall' in campaign_name.lower() or 'autumn' in campaign_name.lower():
        return 'fall'
    elif 'winter' in campaign_name.lower():
        return 'winter'
    else:
        return 'unknown'

df['season']=df['campaign_name'].apply(get_season)
df
# Out:
#   campaign_id             campaign_name start_date    end_date   channel  \
# 0   CMP-00001       Q4_Summer_CMP-00001        NaT  2023-12-13    TikTok
# 1   CMP-00002       Q1_Launch_CMP-00002        NaT  2023-05-12  Facebook
# 2   CMP-00003       Q3_Winter_CMP-00003        NaT  2023-12-20     Email
# 3   CMP-00004  Q1_BlackFriday_CMP-00004        NaT  2023-11-03    TikTok
# 4   CMP-00005       Q2_Winter_CMP-00005        NaT  2023-04-23  Facebook
#
#    impressions  clicks    spend  conversions active  clicks campaign_tag  \
# 0        16795     197   102.82         20.0   True     NaN           TI
# 1         1860      30    24.33          1.0  False     NaN           FA
# 2        77820     843  1323.39         51.0  False     NaN           EM
# 3        55886    2019  2180.38        135.0   True     NaN           TI
# 4         7265     169   252.44         30.0   True     NaN           FA
#
#     season
# 0   summer
# 1  unknown
# 2   winter
# 3  unknown
# 4   winter

# %%
#-------------------------------------------
# Step 7 : how to drop column duplicates
#-------------------------------------------


#🔍 If you want to see the duplicate names before dropping:
df.columns[df.columns.duplicated()]
# Out:
# Index(['clicks'], dtype='object')

# %%
#to drop
df = df.loc[:, ~df.columns.duplicated()]
print("After dropping duplicates : ")
df  # now you can see only one clicks col .................
# Out:
# After dropping duplicates :
#   campaign_id             campaign_name start_date    end_date   channel  \
# 0   CMP-00001       Q4_Summer_CMP-00001        NaT  2023-12-13    TikTok
# 1   CMP-00002       Q1_Launch_CMP-00002        NaT  2023-05-12  Facebook
# 2   CMP-00003       Q3_Winter_CMP-00003        NaT  2023-12-20     Email
# 3   CMP-00004  Q1_BlackFriday_CMP-00004        NaT  2023-11-03    TikTok
# 4   CMP-00005       Q2_Winter_CMP-00005        NaT  2023-04-23  Facebook
#
#    impressions  clicks    spend  conversions active campaign_tag   season
# 0        16795     197   102.82         20.0   True           TI   summer
# 1         1860      30    24.33          1.0  False           FA  unknown
# 2        77820     843  1323.39         51.0  False           EM   winter
# 3        55886    2019  2180.38        135.0   True           TI  unknown
# 4         7265     169   252.44         30.0   True           FA   winter

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    5 non-null      object
#  1   campaign_name  5 non-null      object
#  2   start_date     0 non-null      datetime64[ns]
#  3   end_date       5 non-null      object
#  4   channel        5 non-null      object
#  5   impressions    5 non-null      int64
#  6   clicks         5 non-null      int64
#  7   spend          5 non-null      float64
#  8   conversions    5 non-null      float64
#  9   active         5 non-null      object
#  10  campaign_tag   5 non-null      object
#  11  season         5 non-null      object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 612.0+ bytes

# %%
df['end_date'].dtype # initially the data type is object
df['end_date'] = pd.to_datetime(df['end_date'], format="%Y/%m/%d", errors='coerce')
df['end_date'].dtype # after conversion the data type is datetime64[ns]
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_15744\3350175415.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['end_date'] = pd.to_datetime(df['end_date'], format="%Y/%m/%d", errors='coerce')
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    5 non-null      object
#  1   campaign_name  5 non-null      object
#  2   start_date     0 non-null      datetime64[ns]
#  3   end_date       0 non-null      datetime64[ns]
#  4   channel        5 non-null      object
#  5   impressions    5 non-null      int64
#  6   clicks         5 non-null      int64
#  7   spend          5 non-null      float64
#  8   conversions    5 non-null      float64
#  9   active         5 non-null      object
#  10  campaign_tag   5 non-null      object
#  11  season         5 non-null      object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(6)
# memory usage: 612.0+ bytes

# %%
# -------------------------------------------
# getting q1 or q2 or q3 or q4 from campaign_name
# -------------------------------------------

def get_q(campaign_name):
    campaign_name = campaign_name.lower()
    if 'q1' in campaign_name:
        return 'Q1'
    elif 'q2' in campaign_name:
        return 'Q2'
    elif 'q3' in campaign_name:
        return 'Q3'
    elif 'q4' in campaign_name:
        return 'Q4'
    else:
        return 'Unknown'

df['Quarter']=df['campaign_name'].apply(get_q)

# %%
df.shape
# Out:
# (5, 13)

# %%
df['Quarter']=='Q2'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# Name: Quarter, dtype: bool

# %%
#-------------------------------------------
# when we want data which have quarter 1
#-------------------------------------------

df[df['Quarter']=='Q1']
# Out:
#   campaign_id             campaign_name start_date end_date   channel  \
# 1   CMP-00002       Q1_Launch_CMP-00002        NaT      NaT  Facebook
# 3   CMP-00004  Q1_BlackFriday_CMP-00004        NaT      NaT    TikTok
#
#    impressions  clicks    spend  conversions active campaign_tag   season  \
# 1         1860      30    24.33          1.0  False           FA  unknown
# 3        55886    2019  2180.38        135.0   True           TI  unknown
#
#   Quarter
# 1      Q1
# 3      Q1

# %%
# Getting the dataset in which the channel is facebook

df_facebook = df[df['channel'] == 'Facebook']
df_facebook
# Out:
#   campaign_id        campaign_name start_date end_date   channel  impressions  \
# 1   CMP-00002  Q1_Launch_CMP-00002        NaT      NaT  Facebook         1860
# 4   CMP-00005  Q2_Winter_CMP-00005        NaT      NaT  Facebook         7265
#
#    clicks   spend  conversions active campaign_tag   season Quarter
# 1      30   24.33          1.0  False           FA  unknown      Q1
# 4     169  252.44         30.0   True           FA   winter      Q2

# %%
# clicks greater than 1000

df_high_clicks=df[df['clicks']>1000]
df_high_clicks
# Out:
#   campaign_id             campaign_name start_date end_date channel  \
# 3   CMP-00004  Q1_BlackFriday_CMP-00004        NaT      NaT  TikTok
#
#    impressions  clicks    spend  conversions active campaign_tag   season  \
# 3        55886    2019  2180.38        135.0   True           TI  unknown
#
#   Quarter
# 3      Q1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   campaign_id    5 non-null      object
#  1   campaign_name  5 non-null      object
#  2   start_date     0 non-null      datetime64[ns]
#  3   end_date       0 non-null      datetime64[ns]
#  4   channel        5 non-null      object
#  5   impressions    5 non-null      int64
#  6   clicks         5 non-null      int64
#  7   spend          5 non-null      float64
#  8   conversions    5 non-null      float64
#  9   active         5 non-null      object
#  10  campaign_tag   5 non-null      object
#  11  season         5 non-null      object
#  12  Quarter        5 non-null      object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(7)
# memory usage: 652.0+ bytes

# %%
# i want to convert the objects into binary values
from sklearn.preprocessing import LabelEncoder
import pandas as pd
