# %%
import pandas as pd
import numpy as np

df=pd.read_csv("demo.csv",names=["Name","Age","Platform"])
df
# Out:
#     Name  Age   Platform
# 0  shiva   18     tiktok
# 1  kumar   67      insta
# 2  yadav   89  instagram
# 3   uday   88   tik__tok

# %%
df['Platform'].unique()
# Out:
# array(['tiktok', 'insta', 'instagram', 'tik__tok'], dtype=object)

# %%
clean_platform={
    "insta":"instagram",
    "tik__tok":"tiktok",
}

df['Platform']=df['Platform'].replace(clean_platform)

df
# Out:
#     Name  Age   Platform
# 0  shiva   18     tiktok
# 1  kumar   67  instagram
# 2  yadav   89  instagram
# 3   uday   88     tiktok
